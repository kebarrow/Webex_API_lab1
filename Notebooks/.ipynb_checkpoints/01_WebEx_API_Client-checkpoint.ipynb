# %%
print('a')
# Out:
# a

# %% [markdown]
# # Webex Teams Client API Tutorial
#
# The Webex APIs give you easy access to the Webex Platform to build Bots, Integrations, or Guest Issuer apps. We will work with Integrations in this Notebook. **To get started you need a WebEx Developer Account**.
#
# ### What is Integration?
#
# Integrations are how you request permission to invoke the Webex REST API on behalf of another Webex user. For example, User A wants to some feature such as a messaging platform for his/her website. WebEx Integrations will allow Developers to create that platform in WebEx and integrate it with User A's Website using **Integrations**.
#
# <br />
#
# We will divide this notebook in three steps:
#
# 1. Create Integration.
# 2. Perform Authentication.
# 3. Develop a simple Application to send and recieve messages.
#
# So Let's begin :)

# %% [markdown]
# ## 1. Create Integration
#
# Once you have logged in to your Developer account, click on your account on the top right hand side as shown in Figure.
#
# !...)

# %% [markdown]
# Then click on My Webex Apps. This will prompt you to the Apps page. Currently you would have no App created. So lets start by creating one. Click on "Create an Integration". ![2.png](data:image/png;base64,...)

# %% [markdown]
# Give a good name to your Integration and provide your email address. You can select any icon for your integration. In Description you can write anything as it is a test integration. Now the next thing is a "**redirect url**".
#
#
# ---
#
#
# ### What is a redirect_url?
# This is a url to which API will redirect the user once he/she has allowed the integration. This url is then appended by a unique code which is used for authentication (as we will see later).
#
# For now redirect_url can be anything (literally ANYTHING). For the sake of coherence, we will use https://www.anything.com
#
# Now comes scope.
#
# ---
# ### What is a scope?
# Scopes are permissions granted to your Integration.
# For our purpose, just select "spark:all". This will give us permission to read/write messages, rooms, and peoples.
#
# Click on "Add Integration".
#
# The next page will show you two main things: **client_id** and **client_secret**. Copy them somwhere as we will use them in our next steps.

# %% [markdown]
# ## 2. Perform Authentication
#
# Lets code

# %%
client_id = 'device status update seems to be working or not for yo'  # Paste your client id here
redirect_uri = 'https://www.anything.com'
client_secret = ''  # Paste your client secret here
scopes = 'spark:all spark:kms'

# %% [markdown]
# So now the first step is to seek user's permission to allow your newly registered integration to access/modify your data.
# For this purpose we will send a post request to webex authorize endpoint and recieve a code for authentication.

# %%
# we need the help from an external Python libraries
import urllib.parse
import uuid

# url on which we will send the request for authorization
base_url = 'https://webexapis.com/v1/authorize'

state = str(uuid.uuid4())   # some random UUID
print(f'State: {state}')

# prepare a dictionary with all parameters we need to encode in the URL
data = {
    'client_id' : client_id,
    'response_type' : 'code',  # Telling the API that we need the code
    'redirect_uri' : redirect_uri,
    'scope' : scopes,
    'state' : state
}

# this gets us a url encoded query string
query = urllib.parse.urlencode(data, quote_via=urllib.parse.quote)

# .. which we then finally combine with the base url
url = f'{base_url}?{query}'
print('Click on following link to access code: ')
print(url)

# %% [markdown]
# After clicking on the link above, a new tab will open up. Use the credentials to allow access to integration.
#
# **Note: In this case, we are "The User".**
#
# Now the client will redirect you to our "anything.com" i.e. our redirect_url. Note it also appends the code in front of the url.
#
# Copy the complete URL and paste it in the variable below.

# %%
last_redirect = ''  # Paste the redirect link here

# 1st we parse the URL. We are only interested in the query string
query = urllib.parse.urlparse(last_redirect).query

# then we parse the query string and get a dictionary with key/value pairs
query = urllib.parse.parse_qs(query)

# from that dictionary we finally extract the code
code = query['code'][0]
state = query['state'][0]

print(f'Code: {code}')
print(f'State (same as in the request above!): {state}')

# %% [markdown]
# Now the user has given permissions to our integration. The next thing we need is an access token that we can use to communicate with Webex Teams API. We can get an access token by sending a post request (along with code) to "access_token" endpoint.
#
# **Note: Each code can be used to get only one access token. So if you need another access token, you have to regenerate the code.**

# %%
import requests
import json

access_token_url = 'https://webexapis.com/v1/access_token'

params = {
    'grant_type' : 'authorization_code',  # letting api know that we have authorization code
    'client_id' : client_id,
    'client_secret' : client_secret,
    'code' : code,  # the code we got from redirect_url
    'redirect_uri' : redirect_uri
}

# Sending request
r = requests.post(access_token_url, json = params).json()

print('JSON response:')
print(json.dumps(r, indent=4, sort_keys=True))

if r.get('errors'):
    error = r['errors'][0]
    print(f'Failed to get access token: {error["description"]}')
else:
    access_token = r['access_token']  # Our access token
    refresh_token = r['refresh_token']  # This token is explained later
    
    print(f'\nAccess token: {access_token}')
    print(f'Valid for {round(r["expires_in"] / 60 / 60 / 24)} days')
    print(f'\nRefresh token: {refresh_token}')
    print(f'Valid for {round(r["refresh_token_expires_in"] / 60 / 60 / 24)} days')

# %% [markdown]
# Valid for 14 days?? There is a specific validity limit for each access token. So the question is what to do after this span. This is where our refresh token comes. This refresh token can be used (within 90 days) to get another access token and refresh token.

# %% [markdown]
# ## Develop Simple Application to send and recieve messages

# %% [markdown]
# Lets first use our access token to get out own stats

# %%
url = 'https://webexapis.com/v1/people/me'

# authorization is achieved by passing the access token in an authorization header
headers = {'Authorization' : f'Bearer {access_token}',
          'Content-type' : 'application/json; charset=utf-8'}

r = requests.get(url, headers=headers)

print(json.dumps(r.json(), indent=4, sort_keys=True))

# %% [markdown]
# Now lets list rooms so we know where we can send messages

# %%
url = 'https://webexapis.com/v1/rooms'  # This is the url for rooms api

params = {
    'max': 10,  # Max spaces to display
    'type' : 'direct'  # direct messages only i.e. one-to-one chats
}

# authorization is achieved by passing the access token in an authorization header
headers = {'Authorization' : f'Bearer {access_token}',
          'Content-type' : 'application/json; charset=utf-8'}

r = requests.get(url, params=params, headers=headers)

# raise an exception in case the request failed
r.raise_for_status()

# use the json() method of the response object to get the response
print(json.dumps(r.json(), indent=4, sort_keys=True))

# %% [markdown]
# Lets create a Test Room where we can chat with ourselves and debug the application.

# %%
url = 'https://webexapis.com/v1/rooms'  # This is the url for rooms api

params = {
    'title' : 'Test Room'  # This is the title of the room
}

# authorization is achieved by passing the access token in an authorization header
headers = {'Authorization' : f'Bearer {access_token}',
          'Content-type' : 'application/json; charset=utf-8'}

r = requests.post(url, json=params, headers=headers)

# raise an exception in case the request failed
r.raise_for_status()

# use the json() method of the response object to get the response
print(json.dumps(r.json(), indent=4, sort_keys=True))

# %% [markdown]
# Now we have created the room. Notice in the "type" parameter, it is "group". Now lets list "group" rooms so we can check our newly created room.

# %%
url = 'https://webexapis.com/v1/rooms'  # This is the url for rooms api

params = {
    'max': 10,  # Max spaces to display
    'type' : 'group'  # direct messages only i.e. one-to-one chats
}

# authorization is achieved by passing the access token in an authorization header
headers = {'Authorization' : f'Bearer {access_token}',
          'Content-type' : 'application/json; charset=utf-8'}

r = requests.get(url, params=params, headers=headers)

# raise an exception in case the request failed
r.raise_for_status()

spaces = r.json()['items']

# Lets search all group spaces for our Test Space
titles = [s['title'] for s in spaces]
titles = [t for t in titles if 'Test' in t]
titles.sort()
title_details = [s for s in spaces if s['title'] in titles]

# use the json() method of the response object to get the response
print(json.dumps(title_details, indent=4, sort_keys=True))

# %% [markdown]
# You can see your Test space. Copy its id. We will send a message to this space.
# But first lets see if there is any message already there (which there shouldn't be).

# %%
url = 'https://webexapis.com/v1/messages'
params = {
    'roomId' : 'Y2lzY29zcGFyazovL3VybjpURUFNOmV1LWNlbnRyYWwtMV9rL1JPT00vYTFmYWM1NTAtNzFmMy0xMWViLTk4ODctM2I4M2U1MzQ2YWFj'
}

headers = {
    'Authorization' : f'Bearer {access_token}',
    'Content-Type' : 'application/json; charset=utf-8'
}
r = requests.get(url, params=params, headers=headers)

# use the json() method of the response object to get the response
print(json.dumps(r.json(), indent=4, sort_keys=True))

# %% [markdown]
# Gladly, there isn't any message there. So lets send one.

# %%
headers = {
    'Authorization' : f'Bearer {access_token}',
    'Content-Type' : 'application/json; charset=utf-8'
    }

params = {
    'roomId' : 'Y2lzY29zcGFyazovL3VybjpURUFNOmV1LWNlbnRyYWwtMV9rL1JPT00vYTFmYWM1NTAtNzFmMy0xMWViLTk4ODctM2I4M2U1MzQ2YWFj',
    'text' : 'Is anyone there?'
}

url = 'https://webexapis.com/v1/messages'

r = requests.post(url, json=params, headers=headers)

# use the json() method of the response object to get the response
print(json.dumps(r.json(), indent=4, sort_keys=True))

# %% [markdown]
# Lets create a function which will allow us to display and send messages.

# %%
roomId = 'Y2lzY29zcGFyazovL3VybjpURUFNOmV1LWNlbnRyYWwtMV9rL1JPT00vYTFmYWM1NTAtNzFmMy0xMWViLTk4ODctM2I4M2U1MzQ2YWFj'

def send_message(msg):
  headers = {
    'Authorization' : f'Bearer {access_token}',
    'Content-Type' : 'application/json; charset=utf-8'
    }

  params = {
      'roomId' : roomId,
      'text' : msg
  }

  url = 'https://webexapis.com/v1/messages'

  r = requests.post(url, json=params, headers=headers)

  params = {
    'roomId' : roomId
  }
  r = requests.get(url, params=params, headers=headers)

  r = r.json()
  
  for entry in r['items']:
    print(f"{entry['personEmail']} : {entry['text']}")

# %%
send_client('Yes.')
